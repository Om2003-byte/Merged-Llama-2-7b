# %% [markdown]
# <a href="https://colab.research.google.com/github/Om2003-byte/Merged-Llama-2-7b/blob/dev/Merged_llama_2_7b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install dependencies
# !pip install torch transformers accelerate
# !pip install git+https://github.com/cg123/mergekit
# !pip install torch pyyaml huggingface_hub

from huggingface_hub import login
login("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")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 26.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 30.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 33.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 69.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
from huggingface_hub import snapshot_download

# HF token
token = "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"

# Base model (LLaMA 2 7B)
base_model_path = snapshot_download(
    repo_id="meta-llama/Llama-2-7b",
    token=token,
    local_dir="/content/llama-2-7b"
)

# Chat-tuned model (LLaMA 2 7B Chat)
chat_model_path = snapshot_download(
    repo_id="meta-llama/Llama-2-7b-chat",
    token=token,
    local_dir="/content/llama-2-7b-chat"
)

print("✅ Download complete!")
print("Base model path:", base_model_path)
print("Chat model path:", chat_model_path)
# Out:
# Fetching 10 files:   0%|          | 0/10 [00:00<?, ?it/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# ...

# %%
from huggingface_hub import login

login("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")

# %%
{
  "architectures": ["LlamaForCausalLM"],
  "model_type": "llama",
  "hidden_size": 4096,
  "intermediate_size": 11008,
  "num_attention_heads": 32,
  "num_hidden_layers": 32,
  "vocab_size": 32000
}
# Out:
# {'architectures': ['LlamaForCausalLM'],
#  'model_type': 'llama',
#  'hidden_size': 4096,
#  'intermediate_size': 11008,
#  'num_attention_heads': 32,
#  'num_hidden_layers': 32,
#  'vocab_size': 32000}

# %%
import json
import os

def create_config_json(path):
    config_path = os.path.join(path, "config.json")
    if not os.path.exists(config_path):
        config = {
            "architectures": ["LlamaForCausalLM"],
            "model_type": "llama",
            "torch_dtype": "float16"
        }
        with open(config_path, "w") as f:
            json.dump(config, f, indent=2)
        print(f"✅ Created config.json at {config_path}")
    else:
        print(f"ℹ️ config.json already exists at {config_path}")

create_config_json("/content/llama-2-7b")
create_config_json("/content/llama-2-7b-chat")
# Out:
# ✅ Created config.json at /content/llama-2-7b/config.json
# ✅ Created config.json at /content/llama-2-7b-chat/config.json

# %%
config_content = """
base_model: meta-llama/Llama-2-7b-hf
merge_method: slerp
dtype: float16

models:
  - model: meta-llama/Llama-2-7b-hf
    weight: 0.5
  - model: meta-llama/Llama-2-7b-chat-hf
    weight: 0.5

parameters:
  t: 0.5
"""

with open("/content/linear2.yml", "w") as f:
    f.write(config_content)

# %%
import torch
import yaml
from mergekit.config import MergeConfiguration
from mergekit.merge import MergeOptions, run_merge

CONFIG_YML = "/content/linear2.yml"

with open(CONFIG_YML, "r", encoding="utf-8") as fp:
    merge_config = MergeConfiguration.model_validate(yaml.safe_load(fp))

run_merge(
    merge_config,
    out_path="./models/merged-llama-2-7b",
    options=MergeOptions(
        lora_merge_cache="/tmp",
        cuda=torch.cuda.is_available(),
        copy_tokenizer=True,
        lazy_unpickle=False,
        low_cpu_memory=False,
    ),
)

print("✅ Merge complete!")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/609 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# ...
# Fetching 10 files:   0%|          | 0/10 [00:00<?, ?it/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# ...

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

model_path = "./models/merged-llama-2-7b"
model = AutoModelForCausalLM.from_pretrained(model_path, torch_dtype=torch.float16, device_map="auto")
tokenizer = AutoTokenizer.from_pretrained(model_path)

prompt = "### Instruction:\nExplain how photosynthesis works in simple terms.\n\n### Response:\n"
inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

outputs = model.generate(**inputs, max_new_tokens=200, do_sample=True, temperature=0.7)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING:accelerate.big_modeling:Some parameters are on the meta device because they were offloaded to the cpu.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# ### Instruction:
# Explain how photosynthesis works in simple terms.
#
# ### Response:
#
# Photosynthesis is the process by which green plants, algae, and some bacteria convert light energy from the sun into chemical energy in the form of glucose. This process requires water, carbon dioxide, and sunlight. The chemical equation for photosynthesis is:
#
# 6CO2 + 6H2O + light energy → C6H12O6 (glucose) + 6O2
#
# In simple terms, photosynthesis happens in three steps:
#
# 1. Light energy from the sun is absorbed by special pigments in the leaves of plants called chlorophyll.
# 2. The energy from the light is used to convert carbon dioxide and water into glucose, which is a type of sugar.
# ...

# %%
from huggingface_hub import login

login("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")

# %%
from huggingface_hub import create_repo

create_repo("merged-llama-2-7b-lora2", private=False)

# %%
from huggingface_hub import HfApi, HfFolder, upload_folder

upload_folder(
    folder_path="./models/merged-llama-2-7b",
    repo_id="Om2003/merged-llama-2-7b-lora2",
    repo_type="model",
)
# Out:
# model-00003-of-00003.safetensors:   0%|          | 0.00/3.55G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# Upload 4 LFS files:   0%|          | 0/4 [00:00<?, ?it/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/Om2003/merged-llama-2-7b-lora2/commit/5ce6d22dddfe65fb13e4540f8ae49f4f8f5ec8c0', commit_message='Upload folder using huggingface_hub', commit_description='', oid='5ce6d22dddfe65fb13e4540f8ae49f4f8f5ec8c0', pr_url=None, repo_url=RepoUrl('https://huggingface.co/Om2003/merged-llama-2-7b-lora2', endpoint='https://huggingface.co', repo_type='model', repo_id='Om2003/merged-llama-2-7b-lora2'), pr_revision=None, pr_num=None)
